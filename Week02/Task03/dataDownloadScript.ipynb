# %%
import opendatasets as od

# %%
dataset_link = 'https://www.kaggle.com/competitions/boston-housing/data'

# %%
od.download(dataset_link)
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username:Your Kaggle Key:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 od.download(dataset_link)
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/opendatasets/__init__.py:13, in download(dataset_id_or_url, data_dir, force, dry_run, **kwargs)
#      10 def download(dataset_id_or_url, data_dir='.', force=False, dry_run=False, **kwargs):
#      11     # Check for a Kaggle dataset URL
#      12     if is_kaggle_url(dataset_id_or_url):
# ---> 13         return download_kaggle_dataset(dataset_id_or_url, data_dir=data_dir, force=force, dry_run=dry_run)
#      15     # Check for Google Drive URL
#      16     if is_google_drive_url(dataset_id_or_url):
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/opendatasets/utils/kaggle_api.py:53, in download_kaggle_dataset(dataset_url, data_dir, force, dry_run)
#      51 api.authenticate()
#      52 if dataset_id.split('/')[0] == 'competitions' or dataset_id.split('/')[0] == 'c':
# ---> 53     api.competition_download_files(
#      54         id,
#      55         target_dir,
#      56         force=force,
#      57         quiet=False)
#      58     zip_fname = target_dir + '/' + id + '.zip'
#      59     extract_archive(zip_fname, target_dir)
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/kaggle/api/kaggle_api_extended.py:1116, in KaggleApi.competition_download_files(self, competition, path, force, quiet)
#    1114 request = ApiDownloadDataFilesRequest()
#    1115 request.competition_name = competition
# -> 1116 response = kaggle.competitions.competition_api_client.download_data_files(
#    1117     request)
#    1118 url = response.url.split('?')[0]
#    1119 outfile = os.path.join(effective_path,
#    1120                        competition + '.' + url.split('.')[-1])
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/kagglesdk/competitions/services/competition_api_service.py:129, in CompetitionApiClient.download_data_files(self, request)
#     126 if request is None:
#     127   request = ApiDownloadDataFilesRequest()
# --> 129 return self._client.call("competitions.CompetitionApiService", "ApiDownloadDataFiles", request, HttpRedirect)
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/kagglesdk/kaggle_http_client.py:126, in KaggleHttpClient.call(self, service_name, request_name, request, response_type)
#     123 settings = self._session.merge_environment_settings(http_request.url, {}, None, None, None)
#     124 http_response = self._session.send(http_request, **settings)
# --> 126 response = self._prepare_response(response_type, http_response)
#     127 return response
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/kagglesdk/kaggle_http_client.py:191, in KaggleHttpClient._prepare_response(self, response_type, http_response)
#     189 def _prepare_response(self, response_type, http_response):
#     190   self._print_response(http_response)
# --> 191   http_response.raise_for_status()
#     192   if 'application/json' in http_response.headers['Content-Type']:
#     193     resp = http_response.json()
#
# File ~/.local/lib/python3.12/site-packages/requests/models.py:1026, in Response.raise_for_status(self)
#    1021     http_error_msg = (
#    1022         f"{self.status_code} Server Error: {reason} for url: {self.url}"
#    1023     )
#    1025 if http_error_msg:
# -> 1026     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 403 Client Error: Forbidden for url: https://www.kaggle.com/api/v1/competitions/data/download-all/boston-housing
